# %%
# creating 3d plot using matplotlib
# in python
 
# for creating a responsive plot
# %matplotlib widget
 
# importing required libraries
from mpl_toolkits.mplot3d import Axes3D
import matplotlib._color_data as mcd
import matplotlib.pyplot as plt
import numpy as np

clrs = mcd.CSS4_COLORS
 
point_e = [0,0,0,"E"]

point_qonos = [65,-65,-10,"Qonos"]
points_k = [[115,-350,-40],[350,-115,-50],[305,-305,50]]

point_r = [465,465,10,"Romulus"]
points_r = [[485,335,20],[485,525,20],[565,455,-10],[355,455,30],[475,455,90],[355,475,-105]]

point_c = [-1050,5,105,"Cardassia"]
points_c = [[-1105,-15,95],[-1085,-95,115]]

point_f = [-1050,75,110,"Ferengi"]
points_f = [[-1060,85,120]]

point_bo = [30050,67050,105,"Borg"]
points_bo = [[30020,67050,55],[30050,67020,155],[29020,66550,55],[29050,66920,-155]]

point_d = [-30050,57050,-140,"Dominion"]
points_d = [[-30020,57050,-135],[-30050,57020,-155]]


point_b = [-2150,205,55,"Breen"]
points_b = [[-2050,105,45],[-2050,305,85]]

point_t = [-35,-1550,105,"Tholia"]
points_t = [[-25,-1440,55],[-35,-1440,155]]

point_g = [350,-1100,-240,"Gorn"]
points_g = [[380,-1150,-235],[340,-1120,-255]]

points_civs = [[[-505,1405,-450,"Sheliak", clrs["olive"]], [-535,1485,-460],[-515,1405,-480]],
               [[1050,1150,250,"Republic", clrs["wheat"]], [1080,1250,240],[1150,1180,230]],
               [[-305,2150,-340,"First federation", clrs["gold"]], [-325,2220,-330],[-285,2095,-360]],
               [[450,-2205,-205,"Pakleds", clrs["coral"]], [430,-2155,-215],[440,-2255,-225]],
               [[1550,-2105,205,"Nyberrite Alliance", clrs["goldenrod"]], [1530,-2135,215],[1520,-2035,225]],
               [[28150,66550,105,"Kazon", clrs["olive"]], [28250,66650,-105],[28050,66450,105]],
               [[27850,65550,105,"Krenim", clrs["wheat"]], [27810,65510,105],[27800,65500,-105]],
               [[28290,64550,-405,"Hierarchy", clrs["gold"]], [28210,64590,-305],[28210,64510,-305]],
               [[27830,63550,105,"Hirogen", clrs["goldenrod"]], [27890,63510,-105],[27890,63590,105]],
               [[1950,1850,-150,"Sattaran", clrs["orchid"]], [1920,1850,-140],[1950,1820,-140]],
               [[1850,1950,250,"Lysia", clrs["orangered"]], [1890,1950,220],[1890,1950,220]]]

points_colonies = [[20,5,-5, "Terra Nova"],[-340,-330,495, "Delta Vega"],[290,-1030,-230,"Cestus"]]

# to do - jarada, crysalia, imperium, empire, yotto, sattaran, lysia, madena


points = [[5,15,10,"Vulcan"], [-50,80,20,"Risa"], [-55,5,5,"Xindi"], [-850,55,405,"Tzenketti"], [5,5,-205,"SCP3003"],
          [-105,125, 125,"Schedar"], [405,605,405,"Rigel"], [5,5,-45,"Capella"], [5,0,0,"Alpha Centauri"], [35,15,15,"Zetta Setti"],
          [-1350,305,305,"Deneb"], [-1950,-1950,-405,"Tama"], [-1050,-1050,-305,"Tallar"], [355,-650,-30,"Organia"], [690,-450,-40,"Neural"],
          [0,0,-495,"Cheron"], [-1350,-1505,-305,"Melcor"], [20,105,405,"Arcanar"], [1005,110,120,"Rongovia"], [-1050,10,105,"Bajor"],
          [-805,26050,205,"Sha-ki-ra"],[1050,26050,0,"Cytheria"], [1905,-805,-430,"Kzin"],[0,27050,0,"Central Station"], [0,22050,20,"Firstborn"],
          [-650,-750,-255,"Kiley279"],[-550,-1905,305,"Kesprytt"],[-1930,-835,285,"Antica"],[-1950,-805,305,"Selay"],[-2250,-105,405,"Bynars"],
          [28050,67050,105,"Ocampa"],[28250,66050,-105,"Vadwaur"],[27950,65050,105,"Turei"],[28250,64050,405,"Devora"],[27850,63050,-105,"Pendari"]]

# creating figure
fig = plt.figure()

# ax = Axes3D(fig)
 
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect('equal') 
ax.set_box_aspect(aspect = (50,50,50))

# creating the plot
# plot_geeks = ax.scatter(xs, ys, zs, color='green')


plot_e = ax.scatter(point_e[0], point_e[1], point_e[2], color='blue')
ax.text(point_e[0], point_e[1], point_e[2], point_e[3], color='blue')

plot_q = ax.scatter(point_qonos[0], point_qonos[1], point_qonos[2], color='red')
ax.text(point_qonos[0], point_qonos[1], point_qonos[2], point_qonos[3], color='red')
plot_k = ax.scatter([x for [x,y,z] in points_k], [y for [x,y,z] in points_k], [z for [x,y,z] in points_k], color='red')

plot_r = ax.scatter(point_r[0], point_r[1], point_r[2], color='green')
ax.text(point_r[0], point_r[1], point_r[2], point_r[3], color='green')
plot_rr = ax.scatter([x for [x,y,z] in points_r], [y for [x,y,z] in points_r], [z for [x,y,z] in points_r], color='green')

plot_c = ax.scatter(point_c[0], point_c[1], point_c[2], color='yellow')
ax.text(point_c[0], point_c[1], point_c[2], point_c[3], color='yellow')
plot_cc = ax.scatter([x for [x,y,z] in points_c], [y for [x,y,z] in points_c], [z for [x,y,z] in points_c], color='yellow')

plot_f = ax.scatter(point_f[0], point_f[1], point_f[2], color='violet')
ax.text(point_f[0], point_f[1], point_f[2], point_f[3], color='violet')
plot_ff = ax.scatter([x for [x,y,z] in points_f], [y for [x,y,z] in points_f], [z for [x,y,z] in points_f], color='violet')
 
plot_bo = ax.scatter(point_bo[0], point_bo[1], point_bo[2], color=clrs['lightgreen'])
ax.text(point_bo[0], point_bo[1], point_bo[2], point_bo[3], color=clrs['lightgreen'])
plot_bbo = ax.scatter([x for [x,y,z] in points_bo], [y for [x,y,z] in points_bo], [z for [x,y,z] in points_bo], color=clrs['lightgreen'])

plot_d = ax.scatter(point_d[0], point_d[1], point_d[2], color=clrs['magenta'])
ax.text(point_d[0], point_d[1], point_d[2], point_d[3], color=clrs['magenta'])
plot_dd = ax.scatter([x for [x,y,z] in points_d], [y for [x,y,z] in points_d], [z for [x,y,z] in points_d], color=clrs['magenta'])



plot_b = ax.scatter(point_b[0], point_b[1], point_b[2], color='grey')
ax.text(point_b[0], point_b[1], point_b[2], point_b[3], color='grey')
plot_bb = ax.scatter([x for [x,y,z] in points_b], [y for [x,y,z] in points_b], [z for [x,y,z] in points_b], color='grey')

plot_t = ax.scatter(point_t[0], point_t[1], point_t[2], color='orange')
ax.text(point_t[0], point_t[1], point_t[2], point_t[3], color='orange')
plot_tt = ax.scatter([x for [x,y,z] in points_t], [y for [x,y,z] in points_t], [z for [x,y,z] in points_t], color='orange')

plot_g = ax.scatter(point_g[0], point_g[1], point_g[2], color='brown')
ax.text(point_g[0], point_g[1], point_g[2], point_g[3], color='brown')
plot_gg = ax.scatter([x for [x,y,z] in points_g], [y for [x,y,z] in points_g], [z for [x,y,z] in points_g], color='brown')

plot_b = ax.scatter([x for [x,y,z,t] in points], [y for [x,y,z,t] in points], [z for [x,y,z,t] in points], color='black')
for p in points:
    ax.text(p[0],p[1],p[2],p[3], color="black")
for c in points_civs:
    p = ax.scatter(c[0][0], c[0][1], c[0][2], color=c[0][4])
    ax.text(c[0][0], c[0][1], c[0][2], c[0][3], color=c[0][4])
    plot_ccc = ax.scatter([x for [x,y,z] in c[1:]], [y for [x,y,z] in c[1:]], [z for [x,y,z] in c[1:]], color=c[0][4])
plot_col = ax.scatter([x for [x,y,z,t] in points_colonies], [y for [x,y,z,t] in points_colonies], [z for [x,y,z,t] in points_colonies], marker="^", color="blue")
for c in points_colonies:
    ax.text(c[0],c[1],c[2],c[3], color="blue")

theta = np.linspace(0, 2 * np.pi, 1000)
x = 50000 * np.cos(theta)
y = 50000 * np.sin(theta) + 27050
ax.plot(x, y, 0, color=clrs['cyan'])
xc = 3000 * np.cos(theta)
yc = 3000 * np.sin(theta) + 27050
ax.plot(xc, yc, 0, color=clrs['cyan'])
yy = np.linspace(-23050,77050, 1000)
xx = np.linspace(-50050,50050, 1000)
ax.plot(np.zeros(1000), yy, 0, color=clrs['cyan'])
ax.plot(xx, np.full(1000, 27050), 0, color=clrs['cyan'])

# setting title and labels
ax.set_title("3D plot")
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
ax.view_init(60, 270)
ax.dist = 6
ax.set_xlim3d(-100, 100)
ax.set_ylim3d(-100, 100)
ax.set_zlim3d(-100, 100)
 
# displaying the plot
plt.show()
# Out:
# C:\Users\vmelnyk2\AppData\Local\Temp\ipykernel_39708\2037096616.py:153: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 6
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
